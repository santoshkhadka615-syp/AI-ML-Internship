# %% [markdown]
# Week 4 — Math Intuition for ML + Mini Project
# AI/ML Internship Program — Month 1: Foundations
#
# This notebook covers:
#
# Intuitive math for ML — vectors, matrices, dot products, probability, gradients
# A hands-on gradient descent demo
# Mini Project: Full EDA on a new, independent dataset — the Palmer Penguins dataset

# %% [markdown]
# 1. Vectors, Matrices, and Dot Products
# A vector is just a list of numbers — e.g. a data point with 3 features is a vector in 3D space.
# A matrix is a table of numbers — a full dataset (rows = samples, columns = features) is a matrix.
# The dot product measures how much two vectors "point in the same direction." In ML, it's the core operation behind predictions: prediction = weights · features.
# Matrix multiplication is just doing many dot products at once — this is how a whole dataset gets multiplied by a whole set of weights in one shot.

# %%
pip install numpy pandas matplotlib seaborn scipy scikit-learn
# Out:
# Collecting numpy
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting pandas
#   Using cached pandas-3.0.5-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.11.1-cp311-cp311-win_amd64.whl.metadata (80 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting scipy
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/61.0 kB 165.2 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/61.0 kB 327.7 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 359.6 kB/s eta 0:00:00
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nitro v5\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Using cached tzdata-2026.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Using cached fonttools-4.64.0-cp311-cp311-win_amd64.whl.metadata (126 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.1-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\nitro v5\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (26.3)
# Collecting pillow>=9 (from matplotlib)
#   Using cached pillow-12.3.0-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.6.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.25.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cloudpickle>=3.0 (from joblib>=1.4.0->scikit-learn)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: six>=1.5 in c:\users\nitro v5\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# Using cached pandas-3.0.5-cp311-cp311-win_amd64.whl (10.0 MB)
# Using cached matplotlib-3.11.1-cp311-cp311-win_amd64.whl (9.3 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.1/36.6 MB 2.4 MB/s eta 0:00:16
#    ---------------------------------------- 0.3/36.6 MB 3.3 MB/s eta 0:00:12
#     --------------------------------------- 0.6/36.6 MB 4.1 MB/s eta 0:00:09
#     --------------------------------------- 0.8/36.6 MB 4.8 MB/s eta 0:00:08
#     --------------------------------------- 0.9/36.6 MB 3.7 MB/s eta 0:00:10
#    - -------------------------------------- 1.0/36.6 MB 3.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.2/36.6 MB 3.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.5/36.6 MB 4.0 MB/s eta 0:00:09
#    - -------------------------------------- 1.8/36.6 MB 4.3 MB/s eta 0:00:09
#    -- ------------------------------------- 2.0/36.6 MB 4.5 MB/s eta 0:00:08
#    -- ------------------------------------- 2.3/36.6 MB 4.6 MB/s eta 0:00:08
#    -- ------------------------------------- 2.6/36.6 MB 4.8 MB/s eta 0:00:08
#    --- ------------------------------------ 3.0/36.6 MB 5.0 MB/s eta 0:00:07
#    --- ------------------------------------ 3.5/36.6 MB 5.3 MB/s eta 0:00:07
#    ---- ----------------------------------- 3.9/36.6 MB 5.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.2/36.6 MB 5.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 4.6/36.6 MB 5.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.0/36.6 MB 5.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.3/36.6 MB 5.9 MB/s eta 0:00:06
#    ----- ---------------------------------- 5.3/36.6 MB 5.7 MB/s eta 0:00:06
#    ------ --------------------------------- 5.6/36.6 MB 5.6 MB/s eta 0:00:06
#    ------ --------------------------------- 5.9/36.6 MB 5.7 MB/s eta 0:00:06
#    ------ --------------------------------- 6.2/36.6 MB 5.7 MB/s eta 0:00:06
#    ------- -------------------------------- 6.6/36.6 MB 5.8 MB/s eta 0:00:06
#    ------- -------------------------------- 6.9/36.6 MB 5.9 MB/s eta 0:00:06
#    -------- ------------------------------- 7.3/36.6 MB 6.0 MB/s eta 0:00:05
#    -------- ------------------------------- 7.8/36.6 MB 6.1 MB/s eta 0:00:05
#    -------- ------------------------------- 8.2/36.6 MB 6.2 MB/s eta 0:00:05
#    --------- ------------------------------ 8.6/36.6 MB 6.3 MB/s eta 0:00:05
#    --------- ------------------------------ 8.9/36.6 MB 6.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 9.3/36.6 MB 6.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 9.7/36.6 MB 6.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 10.0/36.6 MB 6.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 10.3/36.6 MB 6.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 10.7
MB 6.5 MB/s eta 0:00:02
#    ------------------------------- -------- 29.2/36.6 MB 6.7 MB/s eta 0:00:02
#    -------------------------------- ------- 29.7/36.6 MB 7.0 MB/s eta 0:00:01
#    -------------------------------- ------- 30.2/36.6 MB 7.4 MB/s eta 0:00:01
#    --------------------------------- ------ 30.7/36.6 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.2/36.6 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.6/36.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.0/36.6 MB 9.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.3/36.6 MB 9.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.7/36.6 MB 9.1 MB/s eta 0:00:01
#    ------------------------------------ --- 33.1/36.6 MB 9.1 MB/s eta 0:00:01
#    ------------------------------------ --- 33.5/36.6 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------ --- 33.7/36.6 MB 9.1 MB/s eta 0:00:01
#    ------------------------------------- -- 34.2/36.6 MB 9.2 MB/s eta 0:00:01
#    ------------------------------------- -- 34.4/36.6 MB 9.1 MB/s eta 0:00:01
#    -------------------------------------- - 35.0/36.6 MB 9.2 MB/s eta 0:00:01
#    -------------------------------------- - 35.3/36.6 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------------  35.8/36.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  36.0/36.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  36.5/36.6 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 8.8 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 8.0 MB/s eta 0:00:00
# Downloading scikit_learn-1.9.0-cp311-cp311-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 10.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.3 MB 9.6 MB/s eta 0:00:01
#    ------ --------------------------------- 1.4/8.3 MB 10.7 MB/s eta 0:00:01
#    -------- ------------------------------- 1.8/8.3 MB 9.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.3 MB 10.8 MB/s eta 0:00:01
#    ------------- -------------------------- 2.9/8.3 MB 10.8 MB/s eta 0:00:01
#    --------------- ------------------------ 3.3/8.3 MB 10.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.7/8.3 MB 10.2 MB/s eta 0:00:01
#    ------------------ --------------------- 3.8/8.3 MB 9.6 MB/s eta 0:00:01
#    -------------------- ------------------- 4.2/8.3 MB 9.2 MB/s eta 0:00:01
#    --------------------- ------------------ 4.5/8.3 MB 9.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.9/8.3 MB 9.0 MB/s eta 0:00:01
#    -------------------------- ------------- 5.4/8.3 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.3 MB 9.1 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.3 MB 9.1 MB/s eta 0:00:01
#    -------------------------------- ------- 6.8/8.3 MB 9.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.3/8.3 MB 9.3 MB/s eta 0:00:01
#    ------------------------------------- -- 7.8/8.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  8.3/8.3 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 9.3 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.64.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Downloading joblib-1.6.0-py3-none-any.whl (306 kB)
#    ---------------------------------------- 0.0/306.1 kB ? eta -:--:--
#    ------------------------------------- - 297.0/306.1 kB 19.1 MB/s eta 0:00:01
#    ---------------------------------------- 306.1/306.1 kB 9.5 MB/s eta 0:00:00
# Using cached kiwisolver-1.5.1-cp311-cp311-win_amd64.whl (70 kB)
# Downloading narwhals-2.25.0-py3-none-any.whl (467 kB)
#    ---------------------------------------- 0.0/467.4 kB ? eta -:--:--
#    ---------------------------------------  460.8/467.4 kB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 467.4/467.4 kB 7.4 MB/s eta 0:00:00
# Using cached pillow-12.3.0-cp311-cp311-win_amd64.whl (7.2 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached tzdata-2026.3-py2.py3-none-any.whl (348 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Installing collected packages: tzdata, threadpoolctl, pyparsing, pillow, numpy, narwhals, kiwisolver, fonttools, cycler, cloudpickle, scipy, pandas, joblib, contourpy, scikit-learn, matplotlib, seaborn
# Successfully installed cloudpickle-3.1.2 contourpy-1.3.3 cycler-0.12.1 fonttools-4.64.0 joblib-1.6.0 kiwisolver-1.5.1 matplotlib-3.11.1 narwhals-2.25.0 numpy-2.4.6 pandas-3.0.5 pillow-12.3.0 pyparsing-3.3.2 scikit-learn-1.9.0 scipy-1.17.1 seaborn-0.13.2 threadpoolctl-3.6.0 tzdata-2026.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: C:\Users\NITRO V5\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np

# A single data point (feature vector): [study_hours, sleep_hours, attendance_pct]
x = np.array([5, 7, 90])

# Weights the model has "learned" for each feature
w = np.array([0.6, 0.3, 0.05])

# Dot product = weighted sum = the model's raw prediction
prediction = np.dot(x, w)
print("Feature vector:", x)
print("Weights:", w)
print("Dot product (prediction):", prediction)
# Out:
# Feature vector: [ 5  7 90]
# Weights: [0.6  0.3  0.05]
# Dot product (prediction): 9.6

# %%
# Matrix multiplication = many dot products at once
# 4 students (rows), 3 features each (columns)
X = np.array([
    [5, 7, 90],
    [2, 5, 60],
    [8, 6, 95],
    [4, 4, 70]
])

predictions = X @ w   # '@' is matrix multiplication in numpy
print("Dataset (4 students x 3 features):\n", X)
print("\nPredictions for all 4 students at once:", predictions)
# Out:
# Dataset (4 students x 3 features):
#  [[ 5  7 90]
#  [ 2  5 60]
#  [ 8  6 95]
#  [ 4  4 70]]
#
# Predictions for all 4 students at once: [ 9.6   5.7  11.35  7.1 ]

# %% [markdown]
# 2. Probability Basics
# Probability = how likely something is, between 0 and 1.
# Conditional probability P(A | B) = probability of A, given that we already know B happened.
# A distribution describes how likely each possible value is. The Normal (bell curve) distribution shows up constantly in ML.

# %%
import numpy as np
rng = np.random.default_rng(42)

# Simulate 1000 students' exam scores, normally distributed
scores = rng.normal(loc=70, scale=10, size=1000)

print(f"Mean score: {scores.mean():.2f}")
print(f"Std dev: {scores.std():.2f}")

# P(score > 85) -- an example of using a distribution to estimate probability
p_above_85 = (scores > 85).mean()
print(f"P(score > 85) ≈ {p_above_85:.3f}")
# Out:
# Mean score: 69.71
# Std dev: 9.89
# P(score > 85) ≈ 0.062

# %% [markdown]
# 3. Derivatives, Gradients & Gradient Descent
# A derivative tells you the slope of a function at a point.
# A gradient generalizes this to multiple variables — it points toward steepest increase.
# Gradient descent = take small steps opposite the gradient to find the minimum. This is how models "learn."
# Below: gradient descent finds the minimum of f(x) = (x - 3)^2, whose true minimum is x = 3.

# %%
import matplotlib.pyplot as plt

def f(x):
    return (x - 3) ** 2

def gradient(x):
    return 2 * (x - 3)

x = -6.0
learning_rate = 0.1
history = [x]

for step in range(30):
    x = x - learning_rate * gradient(x)
    history.append(x)

print(f"Final x after gradient descent: {history[-1]:.4f}  (true minimum is 3)")

xs = np.linspace(-7, 9, 200)
plt.figure(figsize=(7, 4))
plt.plot(xs, f(xs), label="f(x) = (x-3)^2")
plt.plot(history, [f(v) for v in history], 'o-', color='red', label="gradient descent steps")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.title("Gradient Descent Finding the Minimum")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Final x after gradient descent: 2.9889  (true minimum is 3)

# %% [markdown]
# Mini Project: EDA on a New Dataset — Palmer Penguins
# Fresh, independent dataset (not used in Week 2 or Week 3), done end-to-end: load → clean → explore → visualize → summarize.

# %%
import seaborn as sns
df = sns.load_dataset("penguins")
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (344, 7)
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    str
#  1   island             344 non-null    str
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 18.9 KB

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# Cleaning: check and handle missing values

# %%
print("Missing values per column:")
print(df.isnull().sum())

df_clean = df.dropna().reset_index(drop=True)
print(f"\nRows before cleaning: {len(df)}, after cleaning: {len(df_clean)}")
# Out:
# Missing values per column:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
#
# Rows before cleaning: 344, after cleaning: 333

# %% [markdown]
# Exploratory Data Analysis

# %%
import seaborn as sns

plt.figure(figsize=(7, 4))
sns.countplot(data=df_clean, x="species", hue="island")
plt.title("Penguin Species Count by Island")
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
sns.histplot(df_clean["bill_length_mm"], kde=True, ax=axes[0])
axes[0].set_title("Bill Length Distribution")

sns.histplot(df_clean["flipper_length_mm"], kde=True, ax=axes[1])
axes[1].set_title("Flipper Length Distribution")

sns.histplot(df_clean["body_mass_g"], kde=True, ax=axes[2])
axes[2].set_title("Body Mass Distribution")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.boxplot(data=df_clean, x="species", y="body_mass_g")
plt.title("Body Mass by Species")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.scatterplot(data=df_clean, x="flipper_length_mm", y="body_mass_g", hue="species", style="sex")
plt.title("Flipper Length vs Body Mass")
plt.tight_layout()
plt.show()

# %%
numeric_cols = ["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]
corr = df_clean[numeric_cols].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %%
df_clean.groupby("species")[numeric_cols].mean().round(1)
# Out:
#            bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# species
# Adelie               38.8           18.3              190.1       3706.2
# Chinstrap            48.8           18.4              195.8       3733.1
# Gentoo               47.6           15.0              217.2       5092.4

# %% [markdown]
# Written Summary of Findings
# Gentoo penguins are the largest — highest body mass (~5100g avg) and longest flippers among the three species.
# Flipper length and body mass are strongly positively correlated — larger penguins have longer flippers.
# Bill shape separates species better than bill length alone — Adelie has shorter, deeper bills; Chinstrap and Gentoo have longer, shallower ones.
# Island and species are closely linked — Gentoo appears only on Biscoe Island; Adelie appears on all three; Chinstrap only on Dream Island.
# Sex adds a secondary size split within each species — males tend to be slightly larger than females of the same species.
# Connecting back to the math: the correlation heatmap is literally a matrix of dot-product-based similarity scores between features — a direct use of Section 1.
